# %%
# %load_ext autoreload

# %%
# %autoreload 2
import pickle,os
from os import path as osp
import _init_paths
from base_utils import *
import pandas as pd
import numpy as np
import numpy.random as npr
import mnist_loader
from distributions import Gamma
from distributions import WeibullDistribution as Weibull
from distributions import MultinomialDistribution as Multinomial
from processes import PoissonProcess,CRP
import matplotlib.pyplot as plt

# %%
pp = PoissonProcess('c',5)
sample1 = pp.sample(100,sample_type='interval')
pp = PoissonProcess('c',10)
sample2 = pp.sample(100,sample_type='interval')
pp = PoissonProcess('c',1)
sample3 = pp.sample(100,sample_type='interval')
sample4 = npr.uniform(0,100,300)
print(len(sample1))
# T = 10000
# for i in range(T):
#     sample = crp.sample(1)

# print(np.bincount(crp.c))
# # plt.plot(crp.sizes)
fig,ax = plt.subplots(1,2)
ax[0].plot(sample1,'+')
ax[0].plot(sample2,'+')
ax[0].plot(sample3,'+')
ax[0].set_xlabel("Number of Points",fontsize=15)
ax[0].set_ylabel("Time",fontsize=15)

ax[1].set_title("Comparing with Uniform")
ax[1].plot(sample1,sample1,'+')
ax[1].plot(sample2,sample2,'+')
ax[1].plot(sample3,sample3,'+')
ax[1].plot(sample4,sample4,'^',markersize=.5)
# x = np.linspace(1.,T)
# y = crp.alpha * np_loge(x)
# plt.plot(x,y)
plt.show()
print("HI")
# Out:
# c True
# REFACTORED CODE. THIS MAY NOT BE THE SAMPLING YOU WANT!
# mean: 500
# c True
# REFACTORED CODE. THIS MAY NOT BE THE SAMPLING YOU WANT!
# mean: 1000
# c True
# REFACTORED CODE. THIS MAY NOT BE THE SAMPLING YOU WANT!
# mean: 100
# 481
# HI
